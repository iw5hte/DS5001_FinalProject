# %% [markdown]
# # Analyzing Plato's Dialogues
# ## Iris Wu (iw5hte@virginia.edu) DS 5001 Spring 2023

# %% [markdown]
# ## End goal of this notebook:
# - Sentiment and emotion values as features in VOCAB or as a separate table with a shared index with the VOCAB table.
# - Sentiment polarity and emotions for each document.
# - Explore the data.

# %% [markdown]
# ### Setting up necessary tools:
# Importing useful packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
from IPython.display import display, HTML
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from hac2 import HAC

# %% [markdown]
# Setting up configuration for data and functions

# %%
data_in = 'data/output'
data_out = 'data/output'
data_prefix = 'plato'

# %%
emo_cols = "anger anticipation disgust fear joy sadness surprise trust sentiment".split()

OHCO = ['book_id', 'chap_id', 'para_num', 'sent_num', 'token_num']
BOOKS = OHCO[:1]
CHAPS = OHCO[:2]
PARAS = OHCO[:3]
SENTS = OHCO[:4]

republic = 1497
timaeus = 1572
laws = 1750

# %% [markdown]
# Impoting data

# %%
VOCAB = pd.read_csv(f"{data_in}/{data_prefix}-VOCAB-PARA.csv").set_index('term_str').sort_index()
LIB = pd.read_csv(f"{data_in}/{data_prefix}-LIB.csv").set_index('book_id').sort_index()
BOW = pd.read_csv(f"{data_in}/{data_prefix}-BOW-PARA.csv").set_index(['book_id','chap_id', 'para_num', 'term_str']).sort_index()
SALEX = pd.read_csv(f'{data_in}/misc/salex_nrc.csv').set_index('term_str')
TOKENS = pd.read_csv(f"{data_in}/{data_prefix}-CORPUS-PARA.csv").set_index(OHCO).sort_index()

# %%
SALEX.columns = [col.replace('nrc_','') for col in SALEX.columns]
SALEX
# Out:
#              anger  anticipation  disgust  fear  joy  negative  positive  \
# term_str
# abandon          0             0        0     1    0         1         0
# abandoned        1             0        0     1    0         1         0
# abandonment      1             0        0     1    0         1         0
# abduction        0             0        0     1    0         1         0
# aberration       0             0        1     0    0         1         0
# ...            ...           ...      ...   ...  ...       ...       ...
# young            0             1        0     0    1         0         1
# youth            1             1        0     1    1         0         1
# zeal             0             1        0     0    1         0         1
# zealous          0             0        0     0    1         0         1
# zest             0             1        0     0    1         0         1
#
#              sadness  surprise  trust  sentiment
# term_str
# abandon            1         0      0         -1
# abandoned          1         0      0         -1
# abandonment        1         1      0         -1
# abduction          1         1      0         -1
# aberration         0         0      0         -1
# ...              ...       ...    ...        ...
# young              0         1      0          1
# youth              0         1      0          1
# zeal               0         1      1          1
# zealous            0         0      1          1
# zest               0         0      1          1
#
# [3688 rows x 11 columns]

# %% [markdown]
# Adding sentiment values to vocab table

# %%
V = pd.concat([VOCAB.reset_index().set_index('term_str'), SALEX], join='inner', axis=1)
V
# Out:
#               n         p          i  n_chars  \
# term_str
# abandon       1  0.000001  19.494826        7
# aberration    1  0.000001  19.494826       10
# abhor         1  0.000001  19.494826        5
# abject        1  0.000001  19.494826        6
# abolish       2  0.000003  18.494826        7
# ...         ...       ...        ...      ...
# yearning      1  0.000001  19.494826        8
# young       717  0.000970  10.008997        5
# youth       239  0.000323  11.593959        5
# zeal         10  0.000014  16.172898        4
# zealous       3  0.000004  17.909864        7
#
#                                                       cat_pos max_pos  stop  \
# term_str
# abandon                                               {'VBP'}     VBP     0
# aberration                                             {'NN'}      NN     0
# abhor                                                  {'NN'}      NN     0
# abject                                                 {'JJ'}      JJ     0
# abolish                                                {'VB'}      VB     0
# ...                                                       ...     ...   ...
# yearning                                               {'NN'}      NN     0
# young       {'NNP', 'IN', 'JJ', 'NNS', 'LS', 'NN', 'VBZ', ...     NNP     0
# youth       {'NNP', 'VB', 'JJ', 'NNS', 'NN', 'CC', 'RB', '...      NN     0
# zeal                                                   {'NN'}      NN     0
# zealous                                                {'JJ'}      JJ     0
#
#            stem_porter stem_snowball stem_lancaster  ...  anticipation  \
# term_str                                             ...
# abandon        abandon       abandon        abandon  ...             0
# aberration       aberr         aberr           aber  ...             0
# abhor            abhor         abhor            abh  ...             0
# abject          abject        abject         abject  ...             0
# abolish        abolish       abolish           abol  ...             0
# ...                ...           ...            ...  ...           ...
# yearning         yearn         yearn          yearn  ...             1
# young            young         young          young  ...             1
# youth            youth         youth            you  ...             1
# zeal              zeal          zeal           zeal  ...             1
# zealous         zealou       zealous           zeal  ...             0
#
#             disgust  fear  joy  negative  positive  sadness  surprise  trust  \
# term_str
# abandon           0     1    0         1         0        1         0      0
# aberration        1     0    0         1         0        0         0      0
# abhor             1     1    0         1         0        0         0      0
# abject            1     0    0         1         0        0         0      0
# abolish           0     0    0         1         0        0         0      0
# ...             ...   ...  ...       ...       ...      ...       ...    ...
# yearning          0     0    1         1         1        0         0      1
# young             0     0    1         0         1        0         1      0
# youth             0     1    1         0         1        0         1      0
# zeal              0     0    1         0         1        0         1      1
# zealous           0     0    1         0         1        0         0      1
#
#             sentiment
# term_str
# abandon            -1
# aberration         -1
# abhor              -1
# abject             -1
# abolish            -1
# ...               ...
# yearning            0
# young               1
# youth               1
# zeal                1
# zealous             1
#
# [1951 rows x 29 columns]

# %% [markdown]
# Adding sentiment to bag of words

# %%
B = BOW.join(V[['max_pos'] + emo_cols], on='term_str', rsuffix='_v').dropna()
for col in emo_cols:
    B[col] = B[col] * B.tfidf
B
# Out:
#                                      n     tfidf max_pos  anger  anticipation  \
# book_id chap_id para_num term_str
# 1497    1       1        beautiful   1  0.053417      JJ    0.0      0.000000
#                          delighted   1  0.068077      JJ    0.0      0.068077
#                          festival    1  0.069291      NN    0.0      0.069291
#                          procession  1  0.090719      NN    0.0      0.000000
#                          servant     2  0.127545      NN    0.0      0.000000
# ...                                 ..       ...     ...    ...           ...
# 1750    12      121      share       1  0.032315      NN    0.0      0.032315
#                          virtue      1  0.022655      NN    0.0      0.000000
#                 122      share       1  0.199548      NN    0.0      0.199548
#                          stranger    1  0.100531     NNP    0.0      0.000000
#                 123      true        1  0.251828      JJ    0.0      0.000000
#
#                                      disgust      fear       joy   sadness  \
# book_id chap_id para_num term_str
# 1497    1       1        beautiful       0.0  0.000000  0.053417  0.000000
#                          delighted       0.0  0.000000  0.068077  0.000000
#                          festival        0.0  0.000000  0.069291  0.000000
#                          procession      0.0  0.000000  0.090719  0.090719
#                          servant         0.0  0.000000  0.000000  0.000000
# ...                                      ...       ...       ...       ...
# 1750    12      121      share           0.0  0.000000  0.032315  0.000000
#                          virtue          0.0  0.000000  0.000000  0.000000
#                 122      share           0.0  0.000000  0.199548  0.000000
#                          stranger        0.0  0.100531  0.000000  0.000000
#                 123      true            0.0  0.000000  0.251828  0.000000
#
#                                      surprise     trust  sentiment
# book_id chap_id para_num term_str
# 1497    1       1        beautiful   0.000000  0.000000   0.053417
#                          delighted   0.068077  0.000000   0.068077
#                          festival    0.069291  0.000000   0.069291
#                          procession  0.090719  0.000000   0.090719
#                          servant     0.000000  0.127545  -0.127545
# ...                                       ...       ...        ...
# 1750    12      121      share       0.000000  0.032315   0.032315
#                          virtue      0.000000  0.022655   0.022655
#                 122      share       0.000000  0.199548   0.199548
#                          stranger    0.000000  0.000000  -0.100531
#                 123      true        0.000000  0.251828   0.251828
#
# [38851 rows x 12 columns]

# %% [markdown]
# ### Visualizing data

# %% [markdown]
# Part of speech sentiments

# %%
B.max_pos.value_counts().sort_values().plot.barh();

# %% [markdown]
# Sentiment by dialogue

# %%
EMO_BOOKS = B.groupby(['book_id'])[emo_cols].mean()
EMO_BOOKS.index = LIB.raw_title
EMO_CHAPS = B.groupby(['book_id','chap_id'])[emo_cols].mean()
EMO_PARAS = B.groupby(['book_id','chap_id', 'para_num'])[emo_cols].mean()
EMO_BOOKS.plot.barh(figsize=(15,30));

# %% [markdown]
# Republic Sentiments

# %%
EMO_CHAPS.loc[republic].copy().mean().sort_values().plot.barh();

# %% [markdown]
# ### Analysis by chapters

# %%
REPUBLIC_chaps = EMO_CHAPS.loc[republic] 
TIMAEUS_chaps = EMO_CHAPS.loc[timaeus]
LAWS_chaps = EMO_CHAPS.loc[laws]

# %%
REPUBLIC_chaps_thin = EMO_CHAPS.stack().to_frame().reset_index().rename(columns={0:'value','level_2':'emo'}).query("book_id == {}".format(republic))
TMIAEUS_chaps_thin= EMO_CHAPS.stack().to_frame().reset_index().rename(columns={0:'value','level_2':'emo'}).query("book_id == {}".format(timaeus))
LAWS_chaps_thin= EMO_CHAPS.stack().to_frame().reset_index().rename(columns={0:'value','level_2':'emo'}).query("book_id == {}".format(laws))

# %%
def plot_sentiments(df, emo='sentiment'):
    FIG = dict(figsize=(25, 5), legend=True, fontsize=14, rot=45)
    df[emo].plot(**FIG)

# %%
plot_sentiments(REPUBLIC_chaps, ['trust','fear','joy','sentiment'])

# %%
plot_sentiments(LAWS_chaps, ['trust','fear','joy','sentiment'])

# %%
plot_sentiments(TIMAEUS_chaps, ['trust','fear','joy','sentiment'])

# %% [markdown]
# ### Vader analysis

# %%
analyser = SentimentIntensityAnalyzer()

# %%
REPUBLIC2 = T.loc[republic].copy()
REPUBLIC2['html'] = REPUBLIC2.apply(lambda x: "<span class='sent{}'>{}</span>".format(int(np.sign(x['sentiment'])), x.term_str), 1)
REPUBLIC_sents = REPUBLIC2.groupby(SENTS[1:])[emo_cols].mean()
REPUBLIC_sents['sent_str'] = REPUBLIC2.groupby(SENTS[1:]).term_str.apply(lambda x: x.str.cat(sep=' '))
REPUBLIC_sents['html_str'] = REPUBLIC2.groupby(SENTS[1:]).html.apply(lambda x: x.str.cat(sep=' '))

# %%
REPUBLIC_vader_cols = REPUBLIC_sents.sent_str.apply(analyser.polarity_scores).apply(lambda x: pd.Series(x))
REPUBLIC_vader = pd.concat([REPUBLIC_sents, REPUBLIC_vader_cols], axis=1)
w = int(REPUBLIC_vader.shape[0] / 5)
REPUBLIC_vader[['pos','neg']].rolling(w).mean().plot(figsize=(25,5));
REPUBLIC_vader[['neu']].rolling(w).mean().plot(figsize=(25,5));
REPUBLIC_vader[['compound']].rolling(w).mean().plot(figsize=(25,5));

# %% [markdown]
# ### EmoX analysis

# %%
EMOX = B[emo_cols].groupby('book_id').mean()\
    .join(LIB.raw_title).reset_index(drop=True).set_index('raw_title')
EMOX.sort_values('sentiment').style.background_gradient(cmap='Spectral', axis=None)
# Out:
# <style type="text/css">
# #T_97680_row0_col0, #T_97680_row0_col1, #T_97680_row1_col4, #T_97680_row8_col7, #T_97680_row9_col6, #T_97680_row13_col1, #T_97680_row14_col1, #T_97680_row15_col1, #T_97680_row15_col6, #T_97680_row16_col1, #T_97680_row23_col5, #T_97680_row24_col0, #T_97680_row26_col3, #T_97680_row26_col6 {
#   background-color: #ef6645;
#   color: #f1f1f1;
# }
# #T_97680_row0_col2 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_97680_row0_col3, #T_97680_row11_col7, #T_97680_row12_col8, #T_97680_row18_col5, #T_97680_row19_col2, #T_97680_row28_col1 {
#   background-color: #f06744;
#   color: #f1f1f1;
# }
# #T_97680_row0_col4, #T_97680_row14_col7, #T_97680_row21_col8, #T_97680_row22_col8, #T_97680_row24_col1 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_97680_row0_col5, #T_97680_row1_col1, #T_97680_row6_col6, #T_97680_row8_col1, #T_97680_row11_col8, #T_97680_row12_col0, #T_97680_row14_col5, #T_97680_row17_col2, #T_97680_row20_col6, #T_97680_row21_col6, #T_97680_row23_col0, #T_97680_row23_col6 {
#   background-color: #ed6246;
#   color: #f1f1f1;
# }
# #T_97680_row0_col6, #T_97680_row1_col2, #T_97680_row5_col6, #T_97680_row7_col7, #T_97680_row10_col3, #T_97680_row12_col1, #T_97680_row14_col0, #T_97680_row14_col6, #T_97680_row18_col3, #T_97680_row19_col6, #T_97680_row21_col1, #T_97680_row22_col2, #T_97680_row23_col3, #T_97680_row27_col5 {
#   background-color: #ee6445;
#   color: #f1f1f1;
# }
# #T_97680_row0_col7 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_97680_row0_col8 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_97680_row1_col0, #T_97680_row1_col5, #T_97680_row9_col1, #T_97680_row12_col4, #T_97680_row17_col0, #T_97680_row17_col5, #T_97680_row19_col0, #T_97680_row22_col0, #T_97680_row27_col3 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_97680_row1_col3, #T_97680_row10_col7, #T_97680_row16_col8 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_97680_row1_col6, #T_97680_row12_col6, #T_97680_row13_col6 {
#   background-color: #ea5e47;
#   color: #f1f1f1;
# }
# #T_97680_row1_col7, #T_97680_row6_col2, #T_97680_row10_col4, #T_97680_row14_col3, #T_97680_row14_col8, #T_97680_row16_col3, #T_97680_row22_col6, #T_97680_row25_col2 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_97680_row1_col8 {
#   background-color: #d9444d;
#   color: #f1f1f1;
# }
# #T_97680_row2_col0, #T_97680_row2_col5, #T_97680_row5_col3, #T_97680_row20_col0, #T_97680_row20_col3, #T_97680_row25_col3 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_97680_row2_col1, #T_97680_row6_col3, #T_97680_row12_col7, #T_97680_row20_col1, #T_97680_row22_col3, #T_97680_row24_col6 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_97680_row2_col2, #T_97680_row13_col0, #T_97680_row13_col2, #T_97680_row16_col0, #T_97680_row18_col1, #T_97680_row26_col5 {
#   background-color: #f36b43;
#   color: #f1f1f1;
# }
# #T_97680_row2_col3, #T_97680_row17_col4, #T_97680_row20_col8 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_97680_row2_col4, #T_97680_row5_col4, #T_97680_row6_col4, #T_97680_row27_col7 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_97680_row2_col6, #T_97680_row8_col4, #T_97680_row9_col2, #T_97680_row10_col1, #T_97680_row10_col5, #T_97680_row10_col8, #T_97680_row12_col3, #T_97680_row12_col5, #T_97680_row16_col2, #T_97680_row16_col6, #T_97680_row18_col0, #T_97680_row18_col6, #T_97680_row21_col0, #T_97680_row21_col5, #T_97680_row26_col0, #T_97680_row28_col2 {
#   background-color: #eb6046;
#   color: #f1f1f1;
# }
# #T_97680_row2_col7, #T_97680_row5_col5, #T_97680_row6_col7 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_97680_row2_col8 {
#   background-color: #de4c4b;
#   color: #f1f1f1;
# }
# #T_97680_row3_col0, #T_97680_row3_col5, #T_97680_row3_col6, #T_97680_row4_col0, #T_97680_row4_col2, #T_97680_row4_col5, #T_97680_row4_col8, #T_97680_row7_col5, #T_97680_row8_col2, #T_97680_row11_col6 {
#   background-color: #e45549;
#   color: #f1f1f1;
# }
# #T_97680_row3_col1, #T_97680_row3_col3, #T_97680_row4_col1, #T_97680_row4_col3, #T_97680_row5_col8, #T_97680_row7_col2, #T_97680_row7_col3, #T_97680_row7_col6, #T_97680_row10_col2, #T_97680_row11_col2, #T_97680_row27_col2 {
#   background-color: #e55749;
#   color: #f1f1f1;
# }
# #T_97680_row3_col2, #T_97680_row4_col6 {
#   background-color: #e3534a;
#   color: #f1f1f1;
# }
# #T_97680_row3_col4, #T_97680_row3_col7, #T_97680_row4_col4, #T_97680_row6_col8, #T_97680_row7_col0, #T_97680_row8_col5, #T_97680_row8_col6, #T_97680_row10_col6, #T_97680_row11_col0, #T_97680_row21_col2, #T_97680_row24_col2, #T_97680_row26_col2 {
#   background-color: #e75948;
#   color: #f1f1f1;
# }
# #T_97680_row3_col8 {
#   background-color: #e2514a;
#   color: #f1f1f1;
# }
# #T_97680_row4_col7, #T_97680_row7_col1, #T_97680_row7_col4, #T_97680_row8_col3, #T_97680_row9_col8, #T_97680_row10_col0, #T_97680_row12_col2, #T_97680_row14_col2, #T_97680_row18_col2, #T_97680_row27_col0 {
#   background-color: #e95c47;
#   color: #f1f1f1;
# }
# #T_97680_row5_col0, #T_97680_row21_col4, #T_97680_row25_col1 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_97680_row5_col1, #T_97680_row6_col1, #T_97680_row13_col8, #T_97680_row16_col5, #T_97680_row17_col3, #T_97680_row20_col2, #T_97680_row21_col3, #T_97680_row26_col1 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_97680_row5_col2, #T_97680_row15_col3, #T_97680_row19_col8, #T_97680_row22_col5, #T_97680_row24_col5 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_97680_row5_col7 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_97680_row6_col0, #T_97680_row28_col3 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_97680_row6_col5, #T_97680_row14_col4, #T_97680_row15_col0, #T_97680_row17_col8, #T_97680_row18_col8, #T_97680_row19_col3, #T_97680_row22_col1, #T_97680_row25_col0 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_97680_row7_col8, #T_97680_row8_col0, #T_97680_row8_col8, #T_97680_row11_col1, #T_97680_row11_col3, #T_97680_row11_col5, #T_97680_row23_col2 {
#   background-color: #e85b48;
#   color: #f1f1f1;
# }
# #T_97680_row9_col0, #T_97680_row9_col5, #T_97680_row13_col3, #T_97680_row13_col5, #T_97680_row15_col2, #T_97680_row15_col8, #T_97680_row19_col1, #T_97680_row25_col6, #T_97680_row28_col0 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_97680_row9_col3 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_97680_row9_col4 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_97680_row9_col7, #T_97680_row23_col7 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_97680_row11_col4, #T_97680_row17_col6, #T_97680_row23_col1, #T_97680_row24_col3, #T_97680_row28_col6 {
#   background-color: #f26944;
#   color: #f1f1f1;
# }
# #T_97680_row13_col4, #T_97680_row15_col5, #T_97680_row20_col5 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_97680_row13_col7, #T_97680_row23_col8 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_97680_row15_col4, #T_97680_row18_col4 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_97680_row15_col7 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_97680_row16_col4 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_97680_row16_col7, #T_97680_row24_col7 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_97680_row17_col1, #T_97680_row19_col5 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_97680_row17_col7 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_97680_row18_col7 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_97680_row19_col4 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_97680_row19_col7 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_97680_row20_col4, #T_97680_row22_col7, #T_97680_row25_col4 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_97680_row20_col7 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_97680_row21_col7, #T_97680_row23_col4, #T_97680_row24_col4, #T_97680_row24_col8 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_97680_row22_col4 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_97680_row25_col5 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_97680_row25_col7 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_97680_row25_col8 {
#   background-co

# %%
emo_tree = HAC(EMOX)
emo_tree.color_thresh=.03
emo_tree.plot()

# %% [markdown]
# ### Output

# %%
B.to_csv(f"{data_out}/{data_prefix}-SENTBOW.csv")
EMOX.to_csv(f"{data_out}/{data_prefix}-EMOX.csv")
