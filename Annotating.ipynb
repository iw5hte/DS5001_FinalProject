# %% [markdown]
# # Annotating Plato's Dialogues
# ## Iris Wu (iw5hte@virginia.edu) DS 5001 Spring 2023

# %% [markdown]
# ## End goal of this notebook:
# Annotate these tables with statistical and linguistic features using NLP libraries such as NLTK (F3).

# %% [markdown]
# ### Setting up necessary tools:

# %% [markdown]
# Importing useful packages -

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import nltk

# %% [markdown]
# Defining useful filepaths for reading and outputting data -

# %%
data_in = 'data/output'
data_out = 'data/output'
data_prefix = 'plato'

# %% [markdown]
# Setting useful configurations -

# %%
OHCO = ['book_id', 'chap_id', 'para_num', 'sent_num', 'token_num']
SENTS = OHCO[:4]
PARAS = OHCO[:3]
CHAPS = OHCO[:2]
BOOKS = OHCO[:1]

# %% [markdown]
# ### Importing the data -

# %%
LIB = pd.read_csv(f"{data_in}/{data_prefix}-LIB.csv").set_index(BOOKS)
TOKEN = pd.read_csv(f'{data_in}/{data_prefix}-CORPUS.csv').set_index(OHCO).dropna()
VOCAB = pd.read_csv(f'{data_in}/{data_prefix}-VOCAB.csv').set_index('term_str').dropna()
POS = pd.read_csv(f'{data_in}/misc/upenn_tagset.txt', sep='\t', names=['pos_code','def'])

# %% [markdown]
# ### Adding Part of Speech data to TOKEN table -

# %% [markdown]
# Adding number of times a part of speech appears -

# %%
POS = POS[POS.pos_code.str.match(r'^\w')].set_index('pos_code') # Keep only letter codes
POS['n'] = TOKEN.pos.value_counts().to_frame().sort_index()
POS['n'] = POS['n'].fillna(0).astype('int')
POS.sort_values('n', ascending=False)
POS
# Out:
#                                                     def       n
# pos_code
# CC                            conjunction, coordinating   48102
# CD                                    numeral, cardinal    4997
# DT                                           determiner   76691
# EX                                    existential there    2784
# FW                                         foreign word      71
# IN            preposition or conjunction, subordinating   95244
# JJ                        adjective or numeral, ordinal   45019
# JJR                              adjective, comparative    2640
# JJS                              adjective, superlative    1753
# LS                                     list item marker       4
# MD                                      modal auxiliary   17699
# NN                       noun, common, singular or mass  118937
# NNP                              noun, proper, singular   27767
# NNPS                               noun, proper, plural     224
# NNS                                noun, common, plural   23188
# PDT                                      pre-determiner    1174
# POS                                     genitive marker     202
# PRP                                   pronoun, personal   47687
# PRP$                                pronoun, possessive   10911
# RB                                               adverb   34944
# RBR                                 adverb, comparative    1153
# RBS                                 adverb, superlative     676
# RP                                             particle    1322
# SYM                                              symbol       0
# TO             "to" as preposition or infinitive marker   20675
# UH                                         interjection       5
# VB                                      verb, base form   42764
# VBD                                    verb, past tense   13202
# VBG                  verb, present participle or gerund   10214
# VBN                               verb, past participle   15345
# VBP        verb, present tense, not 3rd person singular   26866
# VBZ            verb, present tense, 3rd person singular   24484
# WDT                                       WH-determiner    9285
# WP                                           WH-pronoun    8327
# WP$                              WH-pronoun, possessive     143
# WRB                                           Wh-adverb    4302

# %% [markdown]
# Adding part of speech groups to POS and TOKEN tables -

# %%
POS['pos_group'] = POS.apply(lambda x: x.name[:2], 1)
TOKEN['pos_group'] = TOKEN.pos.str[:2]
TOKEN
# Out:
#                                                        pos_tuple  pos  \
# book_id chap_id para_num sent_num token_num
# 1497    1       1        0        0                 ('I', 'PRP')  PRP
#                                   1              ('went', 'VBD')  VBD
#                                   2               ('down', 'RB')   RB
#                                   3          ('yesterday', 'NN')   NN
#                                   4                 ('to', 'TO')   TO
# ...                                                          ...  ...
# 1750    12      127      0        5             ('EBook', 'NNP')  NNP
#                                   6                 ('of', 'IN')   IN
#                                   7             ('Laws,', 'NNP')  NNP
#                                   8                 ('by', 'IN')   IN
#                                   9             ('Plato', 'NNP')  NNP
#
#                                              token_str   term_str pos_group
# book_id chap_id para_num sent_num token_num
# 1497    1       1        0        0                  I          i        PR
#                                   1               went       went        VB
#                                   2               down       down        RB
#                                   3          yesterday  yesterday        NN
#                                   4                 to         to        TO
# ...                                                ...        ...       ...
# 1750    12      127      0        5              EBook      ebook        NN
#                                   6                 of         of        IN
#                                   7              Laws,       laws        NN
#                                   8                 by         by        IN
#                                   9              Plato      plato        NN
#
# [738801 rows x 5 columns]

# %% [markdown]
# Adding probability and entropy data to POS_GROUP table -

# %%
POS_GROUP = POS.groupby('pos_group').n.sum().to_frame('n')
POS_GROUP = POS_GROUP[POS_GROUP.n > 0]
POS_GROUP['def'] = POS.groupby('pos_group').apply(lambda x: '; '.join(x['def']))
POS_GROUP['p'] = POS_GROUP.n / POS_GROUP.n.sum()
POS_GROUP['i'] = np.log2(1/POS_GROUP.p)
POS_GROUP['h'] = POS_GROUP.p * POS_GROUP.i
POS_GROUP
# Out:
#                 n                                                def  \
# pos_group
# CC          48102                          conjunction, coordinating
# CD           4997                                  numeral, cardinal
# DT          76691                                         determiner
# EX           2784                                  existential there
# FW             71                                       foreign word
# IN          95244          preposition or conjunction, subordinating
# JJ          49412   adjective or numeral, ordinal;  adjective, co...
# LS              4                                   list item marker
# MD          17699                                    modal auxiliary
# NN         170116   noun, common, singular or mass;  noun, proper...
# PD           1174                                     pre-determiner
# PO            202                                    genitive marker
# PR          58598            pronoun, personal;  pronoun, possessive
# RB          36773   adverb;  adverb, comparative;  adverb, superl...
# RP           1322                                           particle
# TO          20675           "to" as preposition or infinitive marker
# UH              5                                       interjection
# VB         132875   verb, base form;  verb, past tense;  verb, pr...
# WD           9285                                      WH-determiner
# WP           8470                WH-pronoun;  WH-pronoun, possessive
# WR           4302                                          Wh-adverb
#
#                   p          i         h
# pos_group
# CC         0.065108   3.941017  0.256593
# CD         0.006764   7.207980  0.048752
# DT         0.103805   3.268057  0.339240
# EX         0.003768   8.051883  0.030342
# FW         0.000096  13.345079  0.001282
# IN         0.128917   2.955486  0.381012
# JJ         0.066881   3.902252  0.260988
# LS         0.000005  17.494826  0.000095
# MD         0.023956   5.383446  0.128968
# NN         0.230260   2.118667  0.487843
# PD         0.001589   9.297610  0.014774
# PO         0.000273  11.836615  0.003236
# PR         0.079315   3.656262  0.289996
# RB         0.049774   4.328467  0.215445
# RP         0.001789   9.126320  0.016331
# TO         0.027985   5.159227  0.144379
# UH         0.000007  17.172898  0.000116
# VB         0.179852   2.475116  0.445155
# WD         0.012568   6.314140  0.079354
# WP         0.011465   6.446680  0.073908
# WR         0.005823   7.424034  0.043230

# %% [markdown]
# ### Annotating VOCAB table -

# %% [markdown]
# Adding probabilities, logs, and numbers of characters for each term -

# %%
VOCAB['p'] = VOCAB.n / VOCAB.n.sum()
VOCAB['i'] = -np.log2(VOCAB.p)
VOCAB['n_chars'] = VOCAB.index.str.len()
VOCAB
# Out:
#             n         p          i  n_chars
# term_str
# 1          38  0.000051  14.246899        1
# 10          1  0.000001  19.494826        2
# 100        13  0.000018  15.794387        3
# 10000       1  0.000001  19.494826        5
# 11          1  0.000001  19.494826        2
# ...        ..       ...        ...      ...
# zones       9  0.000012  16.324901        5
# zopyrus     1  0.000001  19.494826        7
# zoroaster   1  0.000001  19.494826        9
# zosin       1  0.000001  19.494826        5
# zugon       3  0.000004  17.909864        5
#
# [17139 rows x 4 columns]

# %% [markdown]
# Adding all parts of speech -

# %%
VOCAB['cat_pos'] = TOKEN[['term_str','pos']].value_counts().to_frame('n').reset_index()\
    .groupby('term_str').pos.apply(lambda x: set(x))
VOCAB
# Out:
#             n         p          i  n_chars                           cat_pos
# term_str
# 1          38  0.000051  14.246899        1  {PDT, CD, NNP, NN, VBZ, VB, NNS}
# 10          1  0.000001  19.494826        2                              {CD}
# 100        13  0.000018  15.794387        3                              {CD}
# 10000       1  0.000001  19.494826        5                              {CD}
# 11          1  0.000001  19.494826        2                              {CD}
# ...        ..       ...        ...      ...                               ...
# zones       9  0.000012  16.324901        5                    {NNS, NN, VBP}
# zopyrus     1  0.000001  19.494826        7                             {NNP}
# zoroaster   1  0.000001  19.494826        9                             {NNP}
# zosin       1  0.000001  19.494826        5                              {NN}
# zugon       3  0.000004  17.909864        5                     {VB, NNP, NN}
#
# [17139 rows x 5 columns]

# %% [markdown]
# Adding most common part of speech annotation -

# %%
VOCAB['max_pos'] = TOKEN[['term_str','pos']].value_counts().unstack(fill_value=0).idxmax(1)
VOCAB
# Out:
#             n         p          i  n_chars                           cat_pos  \
# term_str
# 1          38  0.000051  14.246899        1  {PDT, CD, NNP, NN, VBZ, VB, NNS}
# 10          1  0.000001  19.494826        2                              {CD}
# 100        13  0.000018  15.794387        3                              {CD}
# 10000       1  0.000001  19.494826        5                              {CD}
# 11          1  0.000001  19.494826        2                              {CD}
# ...        ..       ...        ...      ...                               ...
# zones       9  0.000012  16.324901        5                    {NNS, NN, VBP}
# zopyrus     1  0.000001  19.494826        7                             {NNP}
# zoroaster   1  0.000001  19.494826        9                             {NNP}
# zosin       1  0.000001  19.494826        5                              {NN}
# zugon       3  0.000004  17.909864        5                     {VB, NNP, NN}
#
#           max_pos
# term_str
# 1              CD
# 10             CD
# 100            CD
# 10000          CD
# 11             CD
# ...           ...
# zones         NNS
# zopyrus       NNP
# zoroaster     NNP
# zosin          NN
# zugon          NN
#
# [17139 rows x 6 columns]

# %% [markdown]
# Adding stopword annotation -

# %%
sw = pd.DataFrame(nltk.corpus.stopwords.words('english'), columns=['term_str'])
sw = sw.reset_index().set_index('term_str')
sw.columns = ['dummy']
sw.dummy = 1
VOCAB['stop'] = VOCAB.index.map(sw.dummy)
VOCAB['stop'] = VOCAB['stop'].fillna(0).astype('int')
VOCAB
# Out:
#             n         p          i  n_chars                           cat_pos  \
# term_str
# 1          38  0.000051  14.246899        1  {PDT, CD, NNP, NN, VBZ, VB, NNS}
# 10          1  0.000001  19.494826        2                              {CD}
# 100        13  0.000018  15.794387        3                              {CD}
# 10000       1  0.000001  19.494826        5                              {CD}
# 11          1  0.000001  19.494826        2                              {CD}
# ...        ..       ...        ...      ...                               ...
# zones       9  0.000012  16.324901        5                    {NNS, NN, VBP}
# zopyrus     1  0.000001  19.494826        7                             {NNP}
# zoroaster   1  0.000001  19.494826        9                             {NNP}
# zosin       1  0.000001  19.494826        5                              {NN}
# zugon       3  0.000004  17.909864        5                     {VB, NNP, NN}
#
#           max_pos  stop
# term_str
# 1              CD     0
# 10             CD     0
# 100            CD     0
# 10000          CD     0
# 11             CD     0
# ...           ...   ...
# zones         NNS     0
# zopyrus       NNP     0
# zoroaster     NNP     0
# zosin          NN     0
# zugon          NN     0
#
# [17139 rows x 7 columns]

# %% [markdown]
# Adding three kinds of stems -

# %%
from nltk.stem.porter import PorterStemmer
stemmer1 = PorterStemmer()
VOCAB['stem_porter'] = VOCAB.apply(lambda x: stemmer1.stem(x.name), 1)

from nltk.stem.snowball import SnowballStemmer
stemmer2 = SnowballStemmer("english")
VOCAB['stem_snowball'] = VOCAB.apply(lambda x: stemmer2.stem(x.name), 1)

from nltk.stem.lancaster import LancasterStemmer
stemmer3 = LancasterStemmer()
VOCAB['stem_lancaster'] = VOCAB.apply(lambda x: stemmer3.stem(x.name), 1)
VOCAB
# Out:
#             n         p          i  n_chars                           cat_pos  \
# term_str
# 1          38  0.000051  14.246899        1  {PDT, CD, NNP, NN, VBZ, VB, NNS}
# 10          1  0.000001  19.494826        2                              {CD}
# 100        13  0.000018  15.794387        3                              {CD}
# 10000       1  0.000001  19.494826        5                              {CD}
# 11          1  0.000001  19.494826        2                              {CD}
# ...        ..       ...        ...      ...                               ...
# zones       9  0.000012  16.324901        5                    {NNS, NN, VBP}
# zopyrus     1  0.000001  19.494826        7                             {NNP}
# zoroaster   1  0.000001  19.494826        9                             {NNP}
# zosin       1  0.000001  19.494826        5                              {NN}
# zugon       3  0.000004  17.909864        5                     {VB, NNP, NN}
#
#           max_pos  stop stem_porter stem_snowball stem_lancaster
# term_str
# 1              CD     0           1             1              1
# 10             CD     0          10            10             10
# 100            CD     0         100           100            100
# 10000          CD     0       10000         10000          10000
# 11             CD     0          11            11             11
# ...           ...   ...         ...           ...            ...
# zones         NNS     0        zone          zone            zon
# zopyrus       NNP     0      zopyru       zopyrus          zopyr
# zoroaster     NNP     0     zoroast       zoroast        zoroast
# zosin          NN     0       zosin         zosin          zosin
# zugon          NN     0       zugon         zugon          zugon
#
# [17139 rows x 10 columns]

# %% [markdown]
# Generating TPM table and total number of parts of speech for VOCAB table -

# %%
TPM = TOKEN[['term_str','pos']].value_counts().unstack()
TPM
# Out:
# pos        CC    CD  DT  EX  FW  IN  JJ  JJR  JJS  LS  ...   VB  VBD  VBG  \
# term_str                                               ...
# 1         NaN  24.0 NaN NaN NaN NaN NaN  NaN  NaN NaN  ...  2.0  NaN  NaN
# 10        NaN   1.0 NaN NaN NaN NaN NaN  NaN  NaN NaN  ...  NaN  NaN  NaN
# 100       NaN  13.0 NaN NaN NaN NaN NaN  NaN  NaN NaN  ...  NaN  NaN  NaN
# 10000     NaN   1.0 NaN NaN NaN NaN NaN  NaN  NaN NaN  ...  NaN  NaN  NaN
# 11        NaN   1.0 NaN NaN NaN NaN NaN  NaN  NaN NaN  ...  NaN  NaN  NaN
# ...        ..   ...  ..  ..  ..  ..  ..  ...  ...  ..  ...  ...  ...  ...
# zones     NaN   NaN NaN NaN NaN NaN NaN  NaN  NaN NaN  ...  NaN  NaN  NaN
# zopyrus   NaN   NaN NaN NaN NaN NaN NaN  NaN  NaN NaN  ...  NaN  NaN  NaN
# zoroaster NaN   NaN NaN NaN NaN NaN NaN  NaN  NaN NaN  ...  NaN  NaN  NaN
# zosin     NaN   NaN NaN NaN NaN NaN NaN  NaN  NaN NaN  ...  NaN  NaN  NaN
# zugon     NaN   NaN NaN NaN NaN NaN NaN  NaN  NaN NaN  ...  1.0  NaN  NaN
#
# pos        VBN  VBP  VBZ  WDT  WP  WP$  WRB
# term_str
# 1          NaN  NaN  2.0  NaN NaN  NaN  NaN
# 10         NaN  NaN  NaN  NaN NaN  NaN  NaN
# 100        NaN  NaN  NaN  NaN NaN  NaN  NaN
# 10000      NaN  NaN  NaN  NaN NaN  NaN  NaN
# 11         NaN  NaN  NaN  NaN NaN  NaN  NaN
# ...        ...  ...  ...  ...  ..  ...  ...
# zones      NaN  1.0  NaN  NaN NaN  NaN  NaN
# zopyrus    NaN  NaN  NaN  NaN NaN  NaN  NaN
# zoroaster  NaN  NaN  NaN  NaN NaN  NaN  NaN
# zosin      NaN  NaN  NaN  NaN NaN  NaN  NaN
# zugon      NaN  NaN  NaN  NaN NaN  NaN  NaN
#
# [17139 rows x 35 columns]

# %%
VOCAB['n_pos'] = TPM.count(1)
VOCAB
# Out:
#             n         p          i  n_chars                           cat_pos  \
# term_str
# 1          38  0.000051  14.246899        1  {PDT, CD, NNP, NN, VBZ, VB, NNS}
# 10          1  0.000001  19.494826        2                              {CD}
# 100        13  0.000018  15.794387        3                              {CD}
# 10000       1  0.000001  19.494826        5                              {CD}
# 11          1  0.000001  19.494826        2                              {CD}
# ...        ..       ...        ...      ...                               ...
# zones       9  0.000012  16.324901        5                    {NNS, NN, VBP}
# zopyrus     1  0.000001  19.494826        7                             {NNP}
# zoroaster   1  0.000001  19.494826        9                             {NNP}
# zosin       1  0.000001  19.494826        5                              {NN}
# zugon       3  0.000004  17.909864        5                     {VB, NNP, NN}
#
#           max_pos  stop stem_porter stem_snowball stem_lancaster  n_pos
# term_str
# 1              CD     0           1             1              1      7
# 10             CD     0          10            10             10      1
# 100            CD     0         100           100            100      1
# 10000          CD     0       10000         10000          10000      1
# 11             CD     0          11            11             11      1
# ...           ...   ...         ...           ...            ...    ...
# zones         NNS     0        zone          zone            zon      3
# zopyrus       NNP     0      zopyru       zopyrus          zopyr      1
# zoroaster     NNP     0     zoroast       zoroast        zoroast      1
# zosin          NN     0       zosin         zosin          zosin      1
# zugon          NN     0       zugon         zugon          zugon      3
#
# [17139 rows x 11 columns]

# %% [markdown]
# ### Outputting all the tables as csvs -

# %%
LIB.to_csv(f'{data_out}/{data_prefix}-LIB.csv')
VOCAB.to_csv(f'{data_out}/{data_prefix}-VOCAB.csv')
TOKEN.to_csv(f'{data_out}/{data_prefix}-CORPUS.csv')
POS.to_csv(f"{data_out}/{data_prefix}-POS.csv")
POS_GROUP.to_csv(f"{data_out}/{data_prefix}-POS_GROUP.csv")
